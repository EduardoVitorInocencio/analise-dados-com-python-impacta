# %%
#Importando a biblioteca
import pandas as pd
import numpy as np
import glob as glob
import os as os

# %%
df_happiness = pd.read_csv('world_happiness_report_2015.csv')

# %%
df_happiness.duplicated().sum()
# Out:
# 0

# %%
df_happiness.isna().sum
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13828\2686420294.py in <module>
# ----> 1 df_happiness.isna().sum
#
# NameError: name 'df_happiness' is not defined

# %%
df_happiness.head()
# Out:
#        country          region  happiness rank  happiness score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard error  economy (GDP per Capita)   family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_happiness.rename(columns={'happiness score':'happiness_score',
                             'economy (GDP per Capita)':'PIB',
                             'trust (Government Corruption)':'Corruption',
                             'standard error':'standard_error'
                            },inplace=True)

# %%
df_happiness.head()
# Out:
#        country          region  happiness rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard error      PIB   family  health (Life Expectancy)  freedom  \
# 0         0.03411  1.39651  1.34951                   0.94143  0.66557
# 1         0.04884  1.30232  1.40223                   0.94784  0.62877
# 2         0.03328  1.32548  1.36058                   0.87464  0.64938
# 3         0.03880  1.45900  1.33095                   0.88521  0.66973
# 4         0.03553  1.32629  1.32261                   0.90563  0.63297
#
#    Corruption  generosity  dystopia residual
# 0     0.41978     0.29678            2.51738
# 1     0.14145     0.43630            2.70201
# ...

# %%
#1. Qual a média do score_felicidade?
df_happiness.happiness_score.mean()
# Out:
# 5.424487179487181

# %%
#2. Qual a soma do PIB?
df_happiness.PIB.sum()
# Out:
# 141.37172

# %%
#3. Qual a soma do freedom e corrupcao?
corruption = df_happiness.Corruption.sum()
free = df_happiness.freedom.sum()

total = corruption + free

total
# Out:
# 95.92965000000001

# %%
#4. Há dados duplicados? Quantos? Verifique quais são eles.
df_happiness.loc[df_happiness.duplicated()]
# Out:
#         country                           region  happiness rank  \
# 11       Canada                    North America               5
# 12      Finland                   Western Europe               6
# 13  Netherlands                   Western Europe               7
# 14       Sweden                   Western Europe               8
# 34         Oman  Middle East and Northern Africa              22
# 35    Venezuela      Latin America and Caribbean              23
#
#     happiness_score  standard_error      PIB   family  \
# 11            7.427         0.03553  1.32629  1.32261
# 12            7.406         0.03140  1.29025  1.31826
# 13            7.378         0.02799  1.32944  1.28017
# 14            7.364         0.03157  1.33171  1.28907
# 34            6.853         0.05335  1.36011  1.08182
# 35            6.810         0.06476  1.04424  1.25596
#
#     health (Life Expectancy)  freedom  Corruption  generosity  \
# ...

# %%
#5. Verifique a quantidade de dados faltantes.
df_happiness.isna().sum()
# Out:
# country                      0
# region                       0
# happiness rank               0
# happiness_score              8
# standard_error               1
# PIB                          0
# family                       0
# health (Life Expectancy)     0
# freedom                      0
# Corruption                   0
# generosity                   0
# dystopia residual           14
# dtype: int64

# %%
#6. Crie um novo dataframe onde os valores faltantes de score_
#felicidade sejam substituídos por -9999.

df_happiness_2 = df_happiness.copy()
df_happiness_2['happiness_score'].fillna(-9999,inplace=True)
df_happiness_2.loc[df_happiness_2['happiness_score']==-9999]
# Out:
#                  country                       region  happiness rank  \
# 38              Colombia  Latin America and Caribbean              33
# 42                 Malta               Western Europe              37
# 46   Trinidad and Tobago  Latin America and Caribbean              41
# 58              Paraguay  Latin America and Caribbean              53
# 61             Lithuania   Central and Eastern Europe              56
# 63                  Peru  Latin America and Caribbean              58
# 143                 Mali           Sub-Saharan Africa             138
# 156          Ivory Coast           Sub-Saharan Africa             151
#
#      happiness_score  standard_error      PIB   family  \
# 38           -9999.0         0.05051  0.91861  1.24018
# 42           -9999.0         0.04206  1.20740  1.30203
# 46           -9999.0         0.10895  1.21183  1.18354
# 58           -9999.0         0.04563  0.75985  1.30477
# 61           -9999.0         0.03843  1.14723  1.25745
# ...

# %%
#7. Quantas e quais são regions existentes nos dados?

df_happiness['region'].nunique() #conta os únicos
df_happiness['region'].unique() #retorna os itens únicos
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
len(df_happiness['region'].unique()) #retorna os itens únicos
# Out:
# 10

# %%
#8. Verifique a frequência dos dados segundo suas regiões. Qual a 
#região com maior quantidade de dados? E a região com a menor 
#quantidade?

df_happiness['region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Western Europe                     24
# Latin America and Caribbean        23
# Middle East and Northern Africa    21
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       3
# Australia and New Zealand           2
# Name: region, dtype: int64

# %% [markdown]
# # Pandas - merge, concat

# %% [markdown]
# 1. Crie um dataframe para cada um dos arquivos nba_2015_a.csv,
# nba_2015_b.csv, nba_2015_c.csv, e bust_nba_2015.csv. Chame
# esses dataframes de df_a, df_b, df_c, bust, respectivamente.

# %%
df_a = pd.read_csv('nba_2015_a.csv')
df_b = pd.read_csv('nba_2015_b.csv')
df_c = pd.read_csv('nba_2015_c.csv')
df_d = pd.read_csv('nba_2015_d.csv')

# %% [markdown]
# 2. Visualize o head() de cada um dos dataframes.

# %%
df_a.head()
# Out:
#                Player Position                  ID  Draft Year  Projected SPM  \
# 0  Karl-Anthony Towns        C  karl-anthony-towns        2015       1.030606
# 1     Justise Winslow       SF     justise-winslow        2015       0.875329
# 2     Stanley Johnson       SF     stanley-johnson        2015       0.679493
# 3       Jahlil Okafor        C       jahlil-okafor        2015       0.521661
# 4    D`Angelo Russell       PG    d-angelo-russell        2015       0.511967
#
#    Superstar   Starter  Role Player
# 0   0.134767  0.427183     0.163083
# 1   0.083529  0.510905     0.176767
# 2   0.067800  0.423733     0.278500
# 3   0.058717  0.409900     0.235533
# 4   0.152033  0.342283     0.096583

# %%
df_b.head()
# Out:
#            Player Position              ID  Draft Year  Projected SPM  \
# 0   Austin Rivers       SG   austin-rivers        2012      -0.145824
# 1     Royce White       SF     royce-white        2012      -0.193490
# 2  Damian Lillard       PG  damian-lillard        2012      -0.200562
# 3     Tony Wroten       PG     tony-wroten        2012      -0.245215
# 4      Doron Lamb       SG      doron-lamb        2012      -0.281442
#
#    Superstar   Starter  Role Player
# 0   0.036233  0.268867     0.334098
# 1   0.018400  0.243750     0.357367
# 2   0.036314  0.259300     0.273522
# 3   0.021567  0.280567     0.286900
# 4   0.004280  0.208319     0.439637

# %%
df_c.head()
# Out:
#               Player Position                 ID  Draft Year  Projected SPM  \
# 0     Mustafa Shakur       PG     mustafa-shakur        2007      -1.304224
# 1  Jermareo Davidson       PF  jermareo-davidson        2007      -1.305091
# 2       Ekene Ibekwe       PF       ekene-ibekwe        2007      -1.313002
# 3     Cartier Martin       SF     cartier-martin        2007      -1.315787
# 4     Ivan Radenovic       PF     ivan-radenovic        2007      -1.327384
#
#    Superstar   Starter  Role Player
# 0   0.000728  0.027577     0.328555
# 1   0.000098  0.028128     0.348323
# 2   0.000349  0.018529     0.334192
# 3   0.000206  0.017471     0.363321
# 4   0.000090  0.026357     0.341746

# %%
df_d.head()
# Out:
#              Player Position                ID  Draft Year  Projected SPM  \
# 0   Samardo Samuels       PF   samardo-samuels      2010.0      -1.097613
# 1     Larry Sanders       PF     larry-sanders      2010.0      -1.099703
# 2      Jeremy Evans       SF      jeremy-evans      2010.0      -1.111429
# 3  Stanley Robinson       SF  stanley-robinson      2010.0      -1.116975
# 4     Jerome Randle       PG     jerome-randle      2010.0      -1.146297
#
#    Superstar   Starter  Role Player
# 0   0.001910  0.067415     0.355177
# 1   0.001010  0.067939     0.356190
# 2   0.000000  0.050159     0.397297
# 3   0.000145  0.061203     0.385924
# 4   0.000000  0.044072     0.384182

# %% [markdown]
# 3. Concatene os arquivos df_a, df_b e df_c usando a função
# concat() usando os índices. Salve um dataframe chamado df_total.

# %%
df_total = pd.concat([df_a,df_b,df_c])
df_total
# Out:
#                     Player Position                     ID  Draft Year  \
# 0       Karl-Anthony Towns        C     karl-anthony-towns        2015
# 1          Justise Winslow       SF        justise-winslow        2015
# 2          Stanley Johnson       SF        stanley-johnson        2015
# 3            Jahlil Okafor        C          jahlil-okafor        2015
# 4         D`Angelo Russell       PG       d-angelo-russell        2015
# ..                     ...      ...                    ...         ...
# 384          Terrell Lyday       SG          terrell-lyday        2001
# 385        Brandon Wolfram       SF        brandon-wolfram        2001
# 386  Ruben Boumtje Boumtje        C  ruben-boumtje-boumtje        2001
# 387         Greg Stevenson       SG         greg-stevenson        2001
# 388          Calvin Bowman        C          calvin-bowman        2001
#
#      Projected SPM  Superstar   Starter  Role Player
# 0         1.030606   0.134767  0.427183     0.163083
# ...

# %% [markdown]
# 5. Busque a documentação das funções concat() e merge() e veja
# que outros parâmetros podem ser utilizados.

# %%
df_bust = pd.read_csv('bust_nba_2015.csv')
df_bust
# Out:
#                          ID      Bust
# 0        karl-anthony-towns  0.274967
# 1           justise-winslow  0.228800
# 2           stanley-johnson  0.229967
# 3             jahlil-okafor  0.295850
# 4          d-angelo-russell  0.409100
# ...                     ...       ...
# 1085          terrell-lyday  0.719510
# 1086        brandon-wolfram  0.716636
# 1087  ruben-boumtje-boumtje  0.742427
# 1088         greg-stevenson  0.741446
# 1089          calvin-bowman  0.826303
#
# [1090 rows x 2 columns]

# %%
df_total.merge(df_bust, left_on = "ID", right_on = "ID")
# Out:
#                      Player Position                     ID  Draft Year  \
# 0        Karl-Anthony Towns        C     karl-anthony-towns        2015
# 1           Justise Winslow       SF        justise-winslow        2015
# 2           Stanley Johnson       SF        stanley-johnson        2015
# 3             Jahlil Okafor        C          jahlil-okafor        2015
# 4          D`Angelo Russell       PG       d-angelo-russell        2015
# ...                     ...      ...                    ...         ...
# 1083          Terrell Lyday       SG          terrell-lyday        2001
# 1084        Brandon Wolfram       SF        brandon-wolfram        2001
# 1085  Ruben Boumtje Boumtje        C  ruben-boumtje-boumtje        2001
# 1086         Greg Stevenson       SG         greg-stevenson        2001
# 1087          Calvin Bowman        C          calvin-bowman        2001
#
#       Projected SPM  Superstar   Starter  Role Player      Bust
# ...
